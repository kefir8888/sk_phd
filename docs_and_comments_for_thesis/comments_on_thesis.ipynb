# %% [markdown]
# Synopsis:
# * As for me, the thesis title does not match the topics within the 1.2.1 speciality passport. I would recommend to remove 'robot' and 'system' from it.
# * In Relevance section, please make a special emphasis on algorithms/methods/software as these are the core points of the speciality passport.
# * Seems like you address two problems in your thesis: (i) problem of estimating position, size and orientation of tomatoes and tangerines under the conditions
# close to the real greenhouse, (ii) In this work the the problem of powdery mildew identification is addressed.
# * I strongly recommend to formulate just one problem which is relevant to the speciality passport because the 1st problem sounds as a biology related problem while the 2nd is addressed using hardware.
# * Section 2: typically, there is one goal and multiple objectives.
# * Avoid the objective(s) on a robot development. It is irrelevant for 1.2.1. and is formulated in the way you can buy an off-the-shelf robot.
# * Section 3: you should always match a section title and the section content. If your title is 'Scientific novelty' it puzzles me when in the 1st sentence you speak about 'In terms of the practical results...'.
# * Section 4: I would not  promote the robot (and other hardware/mechanical parts) and TRL as it is the candidate of science dissertation in speciality 1.2.1. and not the Skoltech Innovation Workshop.
# * Section 5: I recommend to formulate the points which are relevant to 1.2.1. Basically, these should be the algoritms/methods with some tangible/numerical results which could be realized by others and you could defend them.
# * Dissertation summary: typically, it is shown with respect to the thesis chapters and demonstrate the most important thesis outcome. Again, I strongly recommend to remove the robot picture because it is not informative, it is not relevant to 1.2.1.

# %%
для роботизации ...

ellipsoidal model for volume estimation

поменять местами оценку урожая и поиск заболеваний

убрать and между авторами

# %%
The thesis is built around two topics: robust quadratic surface fitting for volume estimation of 3D objects (ellipsoidal) and image classification for disease detection. In general the contributions of the thesis are on the integration of the system to the greenhouse environment, showing some promising tasks for the agriculture field. The algorithms used and proposed have marginal contributions and the evaluations reported are narrow (more below).


Some comments about the draft:

* Section "Introduction" is written entirely by bulletpoints. I find this style adequate for an early draft, not for a final document.
* Writing errors, spelling and grammar (p14 -> basing, Thai ber??, In case or..) p22 (in almost solved)
* This statement in p.16 is incorrect: "If presented with a data with a small portion of strong outliers,
least squares method will incorporate those outliers in the calculation of the opti­
mal model parameters, which significantly degraded the quality of the output model.
Consequently, least squares methods cannot be used if significant noise is present."
There is a well established theory around robust factors and weighted LSQ. It presents more limitations than RANSAC, though, but sufficient under the conditions discussed on the thesis.
* No metrics defined in Chapter 2
* Figure 2.3, Shows a constant metric wrt number of inliers. As long as the population of the inliers is the largest, RANSAC should return a correct solution. The question though is why is there such an enormous variability on the results, one should expect that the results provide a precision according to the sensor precision.
* 2.4 Same problem as in 2.3. It is unclear what number of points or other parameters are used (seems like sweeped) to obtain such a large variability on the results
* I think the only relevant graphic is error wrt number of points, say for a particular fraction of outliers. There is too much variability on the plots reported to say anything. Moreover, I dont find where the number of points parameter was specified.
* 2.5 figure missing!
* Table 1 and 2 (p 38) are identical
* Evaluation and discussion about the neural volume prediction (3.3.2) are very scarce. Why pointnet++ is proposed? there are more powerful current architectures, such as TransformerPoint (v3). Why not compare different architectures?
* This paper -> This thesis/chapter
* p84,85, missing tables

# %%
Чёрный шрифт без красного

В интро разделы не должны отображаться в оглавлении; это должны быть абзацы

Список литературы должен быть в оглавлении

Структура диссера в конце интро

В апробации про конфы год, город, страна

Рисунки и таблицы должны быть сразу после упоминания

Не должно быть двоеточие и переход на следующую страницу

Не должно быть ненумерованых заголовков подразделов

Надписи на рисунках минимум 12 шрифтом. На схеме метода слишком маленькие буквы

Рисунков не должно быть внутри предложения

Фигура 2.5 поехала

Название таблицы всегда сверху, рисунка всегда снизу

Сначала ссылка, потом сразу таблица (в том же разделе)

Перед подписью к таблице должно быть немного места

Перед началом разделов должно быть пустое пространство

Каждый абзац с красной строки

Не Fig, а Figure

...на графике на фигуре такой-то

В conclusion не должно быть рисунков, это выводы с обсуждением

Референсы должны быть оформлены единообразно

Для статей на архиве (и других сайтах)  нужно указать дату обращения в формате day of visit 06.11.25

Для статей номер тома, номера страниц, авторы, журнал/конфа

Список таблиц и рисунков: 

1) Table 1: Lala Lalalala

=========

Автореферат

Не делать страницы слева и справа

Межстрочный интервал 1

Общая характеристика должна быть скопирована из диссера

Вместо dissertation summary должно быть the content of the dissertation

Нужен Conclusion (скопированный из диссера)

После conclusion acknowledgements

После этого мои (наши) статьи

Все референсы единообразно
